# %% [markdown]
# <a href="https://colab.research.google.com/github/leuelzewdie/Project-Test/blob/main/Python_project_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Even or odd
number = int(input("Enter a number: "))
if number % 2 == 0:
    print(f"{number} is an even number.")
else:
    print(f"{number} is an odd number.")
# Out:
# Enter a number: 7
# 7 is an odd number.
