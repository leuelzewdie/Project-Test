# %% [markdown]
# <a href="https://colab.research.google.com/github/leuelzewdie/Project-Test/blob/main/Python_project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
birth_year = int(input("Enter your birth year: "))
print("-" * 15)
birth_year = 2026 - birth_year
print(f"You are approximately {birth_year} years old.")
# Out:
# Enter your birth year: 2005
# ---------------
# You are approximately 21 years old.
