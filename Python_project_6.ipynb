# %% [markdown]
# <a href="https://colab.research.google.com/github/leuelzewdie/Project-Test/blob/main/Python_project_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 7
y = 0
z = 3

while y < z:
    y += 1
    m = input("Enter a number: ")
    if int(m) == x:
        print("yup got it")
        break
else:
    print("opps your out of tries")
# Out:
# Enter a number: 7
# yup got it
